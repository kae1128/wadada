# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/CREDIT.csv')
df
# Out:
#            상권_코드_명  기준_년_코드  기준_분기_코드 yearquarter  lease_sole  lease_corp  \
# 0    DMC(디지털미디어시티)     2022         1      2022-1        42.0        11.0
# 1    DMC(디지털미디어시티)     2022         2      2022-2        44.0         9.0
# 2    DMC(디지털미디어시티)     2022         3      2022-3        43.0         6.0
# 3    DMC(디지털미디어시티)     2022         4      2022-4        42.0         6.0
# 4    DMC(디지털미디어시티)     2023         1      2023-1        38.0         6.0
# ..             ...      ...       ...         ...         ...         ...
# 560            화곡역     2022         1      2022-1        15.0         3.0
# 561            화곡역     2022         2      2022-2        16.0         3.0
# 562            화곡역     2022         3      2022-3        18.0         3.0
# 563            화곡역     2022         4      2022-4        18.0         3.0
# 564            화곡역     2023         1      2023-1        18.0         2.0
#
#      owner  is_risky_0  is_risky_1  total_stores_count  ...  \
# ...

# %%
df.groupby('yearquarter').mean()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_7460\1849609290.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('yearquarter').mean()
#              기준_년_코드  기준_분기_코드  lease_sole  lease_corp     owner  is_risky_0  \
# yearquarter
# 2022-1        2022.0       1.0   60.876106    3.823009  0.000000   54.734513
# 2022-2        2022.0       2.0   62.053097    3.911504  0.000000   53.769912
# 2022-3        2022.0       3.0   65.539823    4.159292  0.000000   56.725664
# 2022-4        2022.0       4.0   67.610619    4.469027  0.044248   58.486726
# 2023-1        2023.0       1.0   66.752212    4.504425  0.053097   58.646018
#
#              is_risky_1  total_stores_count  existing_customers_count  \
# yearquarter
# 2022-1         9.982301           64.716814                  2.630568
# ...
