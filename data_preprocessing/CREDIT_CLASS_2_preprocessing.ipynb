# %%
import pandas as pd

# %% [markdown]
# # data description
# - 총 상권 113개
# - 2022-1 ~ 2023-2 6개 분기
# - 업종분류 2 기준 12개 업종으로 분류
# - non-null rows : 1621 / 8136
# - 업종별로 점포 수가 0인 경우 많기 때문에 Nan값이 매우 많음 주의!!

# %%
df = pd.read_csv('../data/credit_class2.csv')
df
# Out:
#            trdar_nm  year  quarter         class_2_name  average(age)  \
# 0     DMC(디지털미디어시티)  2022        1              개인 서비스업           NaN
# 1     DMC(디지털미디어시티)  2023        1  예술, 스포츠 및 여가관련 서비스업           NaN
# 2     DMC(디지털미디어시티)  2023        1               교육서비스업           NaN
# 3     DMC(디지털미디어시티)  2023        1           건강/의료 서비스업           NaN
# 4     DMC(디지털미디어시티)  2023        1              개인 서비스업           NaN
# ...             ...   ...      ...                  ...           ...
# 8131            화곡역  2022        2                   카페           NaN
# 8132            화곡역  2022        2                   일식           NaN
# 8133            화곡역  2022        2                   술집           NaN
# 8134            화곡역  2022        3                   한식           NaN
# 8135            화곡역  2023        2                 전문유통           NaN
#
#       average(duration)  average(is_franchise)  average(business_square_size)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8136 entries, 0 to 8135
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   trdar_nm                             8136 non-null   object
#  1   year                                 8136 non-null   int64
#  2   quarter                              8136 non-null   int64
#  3   class_2_name                         8136 non-null   object
#  4   average(age)                         1621 non-null   float64
#  5   average(duration)                    1621 non-null   float64
#  6   average(is_franchise)                1621 non-null   float64
#  7   average(business_square_size)        1621 non-null   float64
#  8   average(is_risky)                    1621 non-null   float64
#  9   average(monthly_rental_fee)          1621 non-null   float64
#  10  average(regular_employees_count)     1621 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# trdar_nm                                  0
# year                                      0
# quarter                                   0
# class_2_name                              0
# average(age)                           6515
# average(duration)                      6515
# average(is_franchise)                  6515
# average(business_square_size)          6515
# average(is_risky)                      6515
# average(monthly_rental_fee)            6515
# average(regular_employees_count)       6515
# average(rental_deposit)                6515
# average(sum_customer_cnt)              6515
# average(sum_new_customer_cnt)          6515
# average(sum_purchase_card)             6515
# average(sum_purchase_cash)             6515
# average(sum_purchase_invoice)          6515
# average(sum_sales_card)                6515
# average(sum_sales_delivery)            6515
# average(sum_sales_invoice)             6515
# average(sum_weekend_sales_card)        6515
# ...

# %%
df2 = df.dropna()
print(df2.shape)
df2['class_2_name'].nunique()
# Out:
# (1621, 22)
# 12

# %%
df.groupby('class_2_name').mean()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_20700\2185056401.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('class_2_name').mean()
#                             year   quarter  average(age)  average(duration)  \
# class_2_name
# 개인 서비스업              2022.333333  2.166667     38.882128           5.411114
# 건강/의료 서비스업           2022.333333  2.166667     44.011419           6.167897
# 교육서비스업               2022.333333  2.166667     42.147471           5.169546
# 베이커리/디저트             2022.333333  2.166667     32.008809           3.100000
# 술집                   2022.333333  2.166667     40.789692           5.050614
# 양식                   2022.333333  2.166667     39.577602           4.285710
# 예술, 스포츠 및 여가관련 서비스업  2022.333333  2.166667     41.095716           4.626254
# ...
