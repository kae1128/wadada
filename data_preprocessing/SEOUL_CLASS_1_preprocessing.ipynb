# %%
import pandas as pd

# %%
class1 = pd.read_csv('../data/CREDIT_CLASS_1.csv')
class1

# %%
seoul = pd.read_csv('../data/SEOUL.csv')
seoul.drop('경영_위기_비율', axis=1, inplace=True)
seoul
# Out:
#            상권_코드_명    상권_코드  기준_년_코드  기준_분기_코드  유사_업종_점포_수      개업_율  \
# 0    DMC(디지털미디어시티)  2120098     2022         1         766  0.031353
# 1    DMC(디지털미디어시티)  2120098     2022         2         768  0.042763
# 2    DMC(디지털미디어시티)  2120098     2022         3         774  0.035714
# 3    DMC(디지털미디어시티)  2120098     2022         4         778  0.041935
# 4            가락시장역  2120234     2022         1        1203  0.016393
# ..             ...      ...      ...       ...         ...       ...
# 447      홍대입구역(홍대)  2120103     2022         4        2979  0.033623
# 448            화곡역  2120120     2022         1         636  0.024074
# 449            화곡역  2120120     2022         2         634  0.036969
# 450            화곡역  2120120     2022         3         627  0.016822
# 451            화곡역  2120120     2022         4         631  0.024164
#
#          폐업_율  주중_매출_비율  주말_매출_비율  남성_매출_비율  여성_매출_비율  연령대_1020_매출_비율  \
# ...

# %%
class1_isrisky = class1['기준연도', '분기', '상권코드', '업종', '경영_위기_평균']

# %%
pd.merge(class1_isrisky, seoul, on= ['기준연도', '분기', '상권코드'], how='left')
